# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# data to plot
x = np.linspace(0, 2, 1000)
y = np.sin(2 * np.pi * (x - 0.01))

# display the plot
# %matplotlib inline
plt.plot(x, y); plt.show()
